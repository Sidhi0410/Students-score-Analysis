# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('Expanded_data_with_more_features.csv')
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %% [markdown]
# #finding the null entries#

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df.head(10)
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0  female         NaN   bachelor's degree      standard       none
# 1  female     group C        some college      standard        NaN
# 2  female     group B     master's degree      standard       none
# 3    male     group A  associate's degree  free/reduced       none
# 4    male     group C        some college      standard       none
# 5  female     group B  associate's degree      standard       none
# 6  female     group B        some college      standard  completed
# 7    male     group B        some college  free/reduced       none
# 8    male     group D         high school  free/reduced  completed
# 9  female     group B         high school  free/reduced       none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# ...

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of        Gender EthnicGroup          ParentEduc     LunchType   TestPrep  \
# 0      female         NaN   bachelor's degree      standard       none
# 1      female     group C        some college      standard        NaN
# 2      female     group B     master's degree      standard       none
# 3        male     group A  associate's degree  free/reduced       none
# 4        male     group C        some college      standard       none
# ...       ...         ...                 ...           ...        ...
# 30636  female     group D         high school      standard       none
# 30637    male     group E         high school      standard       none
# 30638  female         NaN         high school  free/reduced  completed
# 30639  female     group D  associate's degree      standard  completed
# 30640    male     group B        some college      standard       none
#
#       ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %% [markdown]
# chnage weekly study hours:-

# %%
df["WklyStudyHours"]=df["WklyStudyHours"].str.replace("05-Oct","5-10")

# %%
df["WklyStudyHours"]
# Out:
# 0           < 5
# 1        5 - 10
# 2           < 5
# 3        5 - 10
# 4        5 - 10
#           ...
# 30636    5 - 10
# 30637    5 - 10
# 30638    5 - 10
# 30639    5 - 10
# 30640    5 - 10
# Name: WklyStudyHours, Length: 30641, dtype: object

# %% [markdown]
# Data Transformation Done for the column df["WklyStudyHours"]

# %% [markdown]
# #gender_distribution:-#

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize= (4,4))
ax=sns.countplot(x='Gender',data=df)
plt.title("Gender distribution")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# #female count is 15424 and male is 15217. so by this analysis numbers of female are more than male#

# %% [markdown]
# #LETS FIND OUT THE IMPACT OF PARENTS EDUCATION  ON STUDENT SCORE #

# %%
gb=df.groupby('ParentEduc').agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb)
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
sns.heatmap(gb)
# Out:
# <Axes: ylabel='ParentEduc'>

# %%
sns.heatmap(gb,annot=True)
plt.title("Relationship between parent education and student score")
# Out:
# Text(0.5, 1.0, 'Relationship between parent education and student score')

# %%
sns.heatmap(gb,annot=True)
plt.figure(figsize=(5,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #Analysis we derive from this heat map is average score in math,reading and writing score is higher if parent has done masters and similarly
# #its low if parents are high school passed! herby parent education is impacting more on eductaion.

# %%
gb1=df.groupby('ParentMaritalStatus').agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb1)
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
sns.heatmap(gb1,annot=True)
plt.title("Relationship between parent marital and student score")
plt.figure(figsize=(5,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #From the above chart we have analysed that the marital status of parent has no impact or negligible impact on students score#

# %% [markdown]
#  #Lets analyse the children practice sposrts at regular basis or not#

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
b=sns.countplot(x='PracticeSport',data=df)

# %%
plt.figure(figsize= (4,4))
ax1=sns.countplot(x='PracticeSport',data=df)
plt.title("sport_practice")
ax1.bar_label(ax1.containers[0])
plt.show()

# %%
gb2=df.groupby('PracticeSport').agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb2)
# Out:
#                MathScore  ReadingScore  WritingScore
# PracticeSport
# never          64.171079     68.337662     66.522727
# regularly      67.839155     69.943019     69.604003
# sometimes      66.274831     69.241307     68.072438

# %%
sns.heatmap(gb2,annot=True)
plt.title("Relationship between sports and student score")
plt.figure(figsize=(5,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #there is not such impact of practicing sports on students_score#

# %%
#Impact of lunch on students lunch on studentb score#

# %%
c=sns.countplot(x='LunchType',data=df)

# %% [markdown]
# #impact of test preapartion on students score#

# %%
d=sns.countplot(x='TestPrep',data=df)

# %%
gb3=df.groupby('TestPrep').agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(gb3)
# Out:
#            MathScore  ReadingScore  WritingScore
# TestPrep
# completed   69.54666     73.732998     74.703265
# none        64.94877     67.051071     65.092756

# %%
sns.heatmap(gb3,annot=True)
plt.title("Relationship between test and student score")
plt.figure(figsize=(5,4))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #here come the analysis part those sytudengts who have not completed the test have obtained less score

# %%
sns.boxplot(data=df,x="ReadingScore")
# Out:
# <Axes: xlabel='ReadingScore'>

# %%
sns.boxplot(data=df,x="WritingScore")
# Out:
# <Axes: xlabel='WritingScore'>

# %%
sns.boxplot(data=df,x="MathScore")
# Out:
# <Axes: xlabel='MathScore'>

# %% [markdown]
# #Maths is comparitively the difficult subject for students .#

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
df['EthnicGroup'].unique()
# Out:
# array([nan, 'group C', 'group B', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
groupA=df.loc[(df['EthnicGroup']=='group A')].count()
groupA
# Out:
# Gender                 2219
# EthnicGroup            2219
# ParentEduc             2078
# LunchType              2219
# TestPrep               2081
# ParentMaritalStatus    2121
# PracticeSport          2167
# IsFirstChild           2168
# NrSiblings             2096
# TransportMeans         1999
# WklyStudyHours         2146
# MathScore              2219
# ReadingScore           2219
# WritingScore           2219
# dtype: int64

# %%
groupB=df.loc[(df['EthnicGroup']=='group B')].count()
groupB
# Out:
# Gender                 5826
# EthnicGroup            5826
# ParentEduc             5470
# LunchType              5826
# TestPrep               5488
# ParentMaritalStatus    5605
# PracticeSport          5704
# IsFirstChild           5649
# NrSiblings             5546
# TransportMeans         5238
# WklyStudyHours         5642
# MathScore              5826
# ReadingScore           5826
# WritingScore           5826
# dtype: int64

# %%
groupC=df.loc[(df['EthnicGroup']=='group C')].count()
groupC
# Out:
# Gender                 9212
# EthnicGroup            9212
# ParentEduc             8652
# LunchType              9212
# TestPrep               8652
# ParentMaritalStatus    8858
# PracticeSport          9050
# IsFirstChild           8929
# NrSiblings             8763
# TransportMeans         8280
# WklyStudyHours         8933
# MathScore              9212
# ReadingScore           9212
# WritingScore           9212
# dtype: int64

# %%
groupD=df.loc[(df['EthnicGroup']=='group D')].count()
groupD
# Out:
# Gender                 7503
# EthnicGroup            7503
# ParentEduc             7056
# LunchType              7503
# TestPrep               7070
# ParentMaritalStatus    7218
# PracticeSport          7343
# IsFirstChild           7285
# NrSiblings             7106
# TransportMeans         6713
# WklyStudyHours         7270
# MathScore              7503
# ReadingScore           7503
# WritingScore           7503
# dtype: int64

# %%
groupE=df.loc[(df['EthnicGroup']=='group E')].count()
groupE
# Out:
# Gender                 4041
# EthnicGroup            4041
# ParentEduc             3814
# LunchType              4041
# TestPrep               3804
# ParentMaritalStatus    3892
# PracticeSport          3954
# IsFirstChild           3918
# NrSiblings             3820
# TransportMeans         3624
# WklyStudyHours         3924
# MathScore              4041
# ReadingScore           4041
# WritingScore           4041
# dtype: int64

# %%
groupA=df.loc[(df['EthnicGroup']=='group A')].count()
groupB=df.loc[(df['EthnicGroup']=='group B')].count()
groupC=df.loc[(df['EthnicGroup']=='group C')].count()
groupD=df.loc[(df['EthnicGroup']=='group D')].count()
groupE=df.loc[(df['EthnicGroup']=='group E')].count()
L=['group A','group B','group C','group D','group E']
mlist=[groupA["EthnicGroup"],groupB["EthnicGroup"],groupC["EthnicGroup"],groupD["EthnicGroup"],groupE["EthnicGroup"]]
plt.pie(mlist,labels=L,autopct="%1.2f%%")
plt.show()

# %%
sns.countplot(data=df,x="EthnicGroup")
# Out:
# <Axes: xlabel='EthnicGroup', ylabel='count'>

# %%
ax=sns.countplot(data=df,x="EthnicGroup")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '9212'),
#  Text(0, 0, '5826'),
#  Text(0, 0, '2219'),
#  Text(0, 0, '7503'),
#  Text(0, 0, '4041')]

# %% [markdown]
# ***CONCLUSION***

# %%
##FROM THE ABOVE ANALYSIS WE OBTAINED A CONCLSUION THAT STUDENTS SCORE
###IS GETTING AFFTECTED BY THEIR PARENTS EDUCATION LEVEL AND TEST PREPARATIONS AS WELL.
###Maths is the toughest subejct for these students and there is is spec
